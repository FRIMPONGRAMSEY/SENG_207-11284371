# %% [markdown]
# # FRIMPONG KWAKYE RAMSEY
# ## 11284371
# ### BIOMEDICAL ENGINEERING

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('red_wine.csv')
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
dataset.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
type(dataset.shape)
# Out:
# tuple

# %%
dataset.shape
# Out:
# (1599, 12)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
modified=dataset.dropna()
modified
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
modified.sum
# Out:
# <bound method DataFrame.sum of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
from pandas import Series,DataFrame

# %%
modified.sum(axis=1)
# Out:
# 0        74.54380
# 1       123.05480
# 2        99.69900
# 3       111.55300
# 4        74.54380
#           ...
# 1594    105.49490
# 1595    121.28712
# 1596    100.48174
# 1597    105.21547
# 1598     92.49249
# Length: 1590, dtype: float64

# %%
modified.median()
# Out:
# fixed acidity            7.900000
# volatile acidity         0.520000
# citric acid              0.260000
# residual sugar           2.200000
# chlorides                0.079000
# free sulfur dioxide     14.000000
# total sulfur dioxide    38.000000
# density                  0.996745
# pH                       3.310000
# sulphates                0.620000
# alcohol                 10.200000
# quality                  6.000000
# dtype: float64

# %%
modified.mean()
# Out:
# fixed acidity            8.315849
# volatile acidity         0.527978
# citric acid              0.270786
# residual sugar           2.539277
# chlorides                0.087425
# free sulfur dioxide     15.847170
# total sulfur dioxide    46.357233
# density                  0.996742
# pH                       3.311308
# sulphates                0.658220
# alcohol                 10.428208
# quality                  5.637736
# dtype: float64

# %%
# Checking the maximum value of the data
maximum=modified.max()
maximum
# Out:
# fixed acidity            15.90000
# volatile acidity          1.58000
# citric acid               1.00000
# residual sugar           15.50000
# chlorides                 0.61100
# free sulfur dioxide      72.00000
# total sulfur dioxide    289.00000
# density                   1.00369
# pH                        4.01000
# sulphates                 2.00000
# alcohol                  14.90000
# quality                   8.00000
# dtype: float64

# %%
# Checking the minimum value of the data
minimum=modified.min()
minimum
# Out:
# fixed acidity           4.60000
# volatile acidity        0.12000
# citric acid             0.00000
# residual sugar          0.90000
# chlorides               0.01200
# free sulfur dioxide     1.00000
# total sulfur dioxide    6.00000
# density                 0.99007
# pH                      2.74000
# sulphates               0.33000
# alcohol                 8.40000
# quality                 3.00000
# dtype: float64

# %%
# Calculating the standard deviation
modified.std()
# Out:
# fixed acidity            1.742820
# volatile acidity         0.179108
# citric acid              0.194780
# residual sugar           1.412957
# chlorides                0.047135
# free sulfur dioxide     10.434785
# total sulfur dioxide    32.812400
# density                  0.001889
# pH                       0.154489
# sulphates                0.169622
# alcohol                  1.066296
# quality                  0.808753
# dtype: float64

# %%
# Calculating the variance
modified.var()
# Out:
# fixed acidity              3.037420
# volatile acidity           0.032080
# citric acid                0.037939
# residual sugar             1.996447
# chlorides                  0.002222
# free sulfur dioxide      108.884747
# total sulfur dioxide    1076.653613
# density                    0.000004
# pH                         0.023867
# sulphates                  0.028772
# alcohol                    1.136988
# quality                    0.654082
# dtype: float64

# %%
# Listing all information on one table
modified.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1590.000000       1590.000000  1590.000000     1590.000000
# mean        8.315849          0.527978     0.270786        2.539277
# std         1.742820          0.179108     0.194780        1.412957
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1590.000000          1590.000000           1590.000000  1590.000000
# mean      0.087425            15.847170             46.357233     0.996742
# std       0.047135            10.434785             32.812400     0.001889
# ...

# %%
fig, axs=plt.subplots(1,2)
axs[0].bar(modified.index , modified['fixed acidity'])
axs[0].set_title('A GRAPH OF ACIDITY CONTENT')
axs[0].set_xlabel('fixed acidity ')
axs[0].set_ylabel('Data')
axs[1].bar(modified.index , modified['fixed acidity'])
axs[1].set_title('A GRAPH OF ACIDITY CONTENT')
axs[1].set_xlabel('volatile acidity ')
axs[1].set_ylabel('Data')
plt.tight_layout()
plt.show()

# %%
print(modified.corr())
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.254341     0.671312
# volatile acidity          -0.254341          1.000000    -0.551409
# citric acid                0.671312         -0.551409     1.000000
# residual sugar             0.115045          0.001421     0.144175
# chlorides                  0.093711          0.060803     0.205018
# free sulfur dioxide       -0.155482         -0.011571    -0.061793
# total sulfur dioxide      -0.113596          0.074772     0.036837
# density                    0.667684          0.023179     0.363958
# pH                        -0.683890          0.235076    -0.544230
# sulphates                  0.181817         -0.261613     0.313335
# alcohol                   -0.060368         -0.203852     0.111092
# quality                    0.124716         -0.391009     0.227406
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
# The heat map of the entire data
sns.heatmap(modified.corr(),annot=True,cmap='YlGnBu')
plt.show()

# %%
fig, ax=plt.subplots(1,2)
ax[0].bar(modified.index , modified['free sulfur dioxide'])
ax[0].set_title('A GRAPH OF SULFUR DIOXIDE CONTENT')
ax[0].set_xlabel('fixed free sulfur dioxide  ')
ax[0].set_ylabel('Data')
ax[1].bar(modified.index , modified['total sulfur dioxide'])
# ax[1].set_title( 'A GRAPH OF SULFUR DIAOXIDE CONTENT')
ax[1].set_xlabel('total sulfur dioxide ')
ax[1].set_ylabel('Data')
plt.tight_layout()
plt.show()

# %%
fig, ax=plt.subplots(1,2)
ax[0].bar(modified.index , modified['quality'])
ax[0].set_title('A GRAPH OF QUALITY CONTENT')
ax[0].set_xlabel('quality  ')
ax[0].set_ylabel('Data')
ax[1].bar(modified.index , modified['alcohol'])
ax[1].set_title('A GRAPH OF ALCOHOL CONTENT')
ax[1].set_xlabel('alcohol  ')
ax[1].set_ylabel('Data')

plt.show()

# %%
fig, ax=plt.subplots(1,2)
ax[0].bar(modified.index , modified['pH'])
ax[0].set_title('A GRAPH OF PH CONTENT')
ax[0].set_xlabel('pH  ')
ax[0].set_ylabel('Data')
ax[1].bar(modified.index , modified['density'])
ax[1].set_title('A GRAPH OF Density CONTENT')
ax[1].set_xlabel('density  ')
ax[1].set_ylabel('Data')

plt.show()

# %%
fig, ax=plt.subplots(1,2)
ax[0].bar(modified.index , modified['citric acid'])
ax[0].set_title('A GRAPH OF CITRIC ACID CONTENT')
ax[0].set_xlabel('citric acid  ')
ax[0].set_ylabel('Data')
ax[1].bar(modified.index , modified['residual sugar'])
ax[1].set_title('A GRAPH OF RESIDUAL SUGAR  CONTENT')
ax[1].set_xlabel('residual sugar  ')
ax[1].set_ylabel('Data')

plt.show()

# %%
fig, ax=plt.subplots(1,2)
ax[0].bar(modified.index , modified['chlorides'])
ax[0].set_title('A GRAPH OF CHLORIDE CONTENT')
ax[0].set_xlabel('chloride  ')
ax[0].set_ylabel('Data')
ax[1].bar(modified.index , modified['sulphates'])
ax[1].set_title('A GRAPH OF SULPHATE  CONTENT')
ax[1].set_xlabel('sulphate  ')
ax[1].set_ylabel('Data')

plt.show()

# %% [markdown]
# # REPORT ON ALL PLOTS AND GRAPH OBTAINED.
#
# * A heat map was used to determine the intensity of the given information with colours ranging from light yellow to deep blue .The indication is that when any value of the provided data is given ,it can be mapped directly from the heat table to find out whether it is of lower or higher intensity.
#
# * Bar charts were also used in reporting the given data.
# * From the bar chart statistics, free sulphur diaoxide were greater in most of the red_wine than the actual total sulphur diaoxide.
# * Most of the red_wine had a pH between 3.0-3.5
# * Most of the data on red_wine accounted for low chloride content.
# * Most of the data on the red_wine accounted for residual sugar content between 2-4 ,but with higher content of 8.3
# * Almost all the data on red_wine accounted similar densities.
# * Most of the dataset on red_wine accounted for moderate sulphate content.
